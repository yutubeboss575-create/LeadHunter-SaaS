# %% [markdown]
# <a href="https://colab.research.google.com/github/yutubeboss575-create/LeadHunter-SaaS/blob/main/wan2gp-google-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%bash
#
# cd /content
#
# rm -rf Wan2GP
#
# git clone https://github.com/Square-Zero-Labs/Wan2GP.git
#
# cd Wan2GP
#
# echo "=== Wan2GP ==="
# git log -1 --oneline
# echo "=== FILES ==="
# ls
# Out:
# === Wan2GP ===
# 143ae897 added H3 Face Refiner, H3 Two Phases Upsampler with tiles, SenseNova 1.5, Deepy support for Codex, Claude & OpenCode
# === FILES ===
# Custom Resolutions Instructions.txt
# defaults
# Dockerfile
# docs
# entrypoint.sh
# favicon.png
# finetunes
# icons
# LICENSE.txt
# models
# plugins
# plugins.json
# postprocessing
# preprocessing
# profiles
# README.md
# requirements.txt
# run-docker-cuda-deb.sh
# scripts
# setup_config.json
# setup.py
# shared
# wangp-agent
# wgp.py
# Cloning into 'Wan2GP'...

# %%
# %%bash
#
# cd /content/Wan2GP
#
# python setup.py --help
# Out:
# usage: setup.py [-h] [--env ENV] [--auto]
#                 {install,update,upgrade,status,manage,get_env_info}
#
# positional arguments:
#   {install,update,upgrade,status,manage,get_env_info}
#
# options:
#   -h, --help            show this help message and exit
#   --env ENV             Type of env for install (venv, uv, conda, none)
#   --auto                Run 1-click automatic install

# %%
# %%bash
#
# cd /content/Wan2GP
#
# echo "========================================"
# echo "      WAN2GP DEPENDENCY INSTALL"
# echo "========================================"
# echo ""
#
# echo "[1/3] Python"
# python --version
#
# echo ""
# echo "[2/3] GPU"
# nvidia-smi --query-gpu=name,memory.total --format=csv,noheader
#
# echo ""
# echo "[3/3] Installing requirements..."
# echo "========================================"
#
# python -m pip install -r requirements.txt --verbose 2>&1 | tee /content/wan2gp_install.log
#
# echo ""
# echo "========================================"
# echo "       INSTALLATION FINISHED"
# echo "========================================"
#
# echo ""
# echo "Last 30 log lines:"
# tail -30 /content/wan2gp_install.log
# Out:
# ...
#       WAN2GP DEPENDENCY INSTALL
# ...
#
# [1/3] Python
# Python 3.13.15
#
# [2/3] GPU
# Tesla T4, 15360 MiB
#
# [3/3] Installing requirements...
# ...
# Using pip 24.1.2 from /usr/local/lib/python3.13/dist-packages/pip (python 3.13)
# WARNING: Ignoring invalid distribution ~radio (/usr/local/lib/python3.13/dist-packages)
# Looking in indexes: https://pypi.org/simple, https://aiinfra.pkgs.visualstudio.com/PublicPackages/_packaging/ort-cuda-13-nightly/pypi/simple/
# Ignoring rembg: markers 'platform_system == "Darwin"' don't match your environment
# Ignoring onnxruntime-gpu: markers 'python_version < "3.11" and platform_system != "Darwin"' don't match your environment
# Ignoring onnxruntime: markers 'platform_system == "Darwin"' don't match your environment
# Ignoring insightface: markers 'sys_platform == "win32" and python_version == "3.10"' don't match your environment
# Ignoring insightface: markers 'sys_platform == "win32" and python_version == "3.11"' don't match your environment
# ...

# %%
# !cd /content/Wan2GP && PYTHONUNBUFFERED=1 python -u wgp.py --share --server-port 7860 2>&1
# Out:
# [GGUF][llama.cpp CUDA] kernels unavailable, using fallback
# Switching to FP16 models when possible as GPU architecture doesn't support optimed BF16 Kernels
# Loaded plugin: Motion Designer (from motion_designer)
# /usr/local/lib/python3.13/dist-packages/gradio/components/dropdown.py:227: UserWarning: The value passed into gr.Dropdown() is not in the list of choices. Please update the list of choices to include:  or set allow_custom_value=True.
#   warnings.warn(
# * Running on local URL:  http://localhost:7860
# * Running on public URL: https://f65f520dc701fbae7d.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Loading Model 'ckpts/wan2.2_text2video_5B_quanto_mbf16_int8.safetensors' ...
# Loading Text Encoder 'ckpts/umt5-xxl/models_t5_umt5-xxl-enc-quanto_int8.safetensors' ...
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
